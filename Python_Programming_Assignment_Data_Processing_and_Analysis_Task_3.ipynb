# %% [markdown]
# <a href="https://colab.research.google.com/github/JEEVITHRAM72/Data-Science-Internship-February-2026/blob/main/Python_Programming_Assignment_Data_Processing_and_Analysis_Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Programming Assignment
# Data Processing and Analysis

# Problem 1

employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}

highest_score = max(employees.values())

top_performers = [name for name, score in employees.items() if score == highest_score]

print("Top Performers Eligible for Bonus:", ", ".join(top_performers), f"(Score: {highest_score})")


# Problem 2

query = "Buy mobile phone buy phone online"

query = query.lower()

for ch in ".,!?;:":
    query = query.replace(ch, "")

words = query.split()

frequency = {}
for word in words:
    frequency[word] = frequency.get(word, 0) + 1

result = {word: count for word, count in frequency.items() if count > 1}

print(result)


# Problem 3

sensor_readings = [3, 4, 7, 8, 10, 12, 5]

valid_readings = []

for index, value in enumerate(sensor_readings):
    if value % 2 == 0:
        valid_readings.append((index, value))

print("Valid Sensor Readings (Hour, Value):")
print(valid_readings)


# Problem 4

emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]

domain_count = {}

for email in emails:
    domain = email.split("@")[1]
    domain_count[domain] = domain_count.get(domain, 0) + 1

total_users = len(emails)

for domain, count in domain_count.items():
    percentage = (count / total_users) * 100
    print(f"{domain}: {percentage:.0f}%")


# Problem 5

sales = [1200, 1500, 900, 2200, 1400, 3000]

average_sales = sum(sales) / len(sales)

threshold = average_sales * 1.30

for day, value in enumerate(sales, start=1):
    if value > threshold:
        print(f"Day {day}: {value}")


# Problem 6

user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]

id_count = {}

for uid in user_ids:
    id_count[uid] = id_count.get(uid, 0) + 1

for uid, count in id_count.items():
    if count > 1:
        print(f"{uid} → {count} times")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)
# {'buy': 2, 'phone': 2}
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]
# gmail.com: 60%
# yahoo.com: 40%
# Day 6: 3000
# user1 → 3 times
# user3 → 2 times
